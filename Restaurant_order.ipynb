# %%
### Creating restaurant Order details

print("Here is the Menu sir: ")
hotel_menu = {
    'chai': 3.50,
    'coffee': 3.50,
    'milk': 3.00,
    'water': 0,
    'buffet': 14.00,
    'chicken biryani': 10.00,
    'Mutton biryani': 14.00,
    'chicken 65 biryani': 10.00,
    'paneer biryani': 10.00,
    'veg biryani': 9.00,
    'non-veg pulao': 12.00,
    'roti': 2.50,
    'butter naan': 4.00,
    'chicken curry':10.00,
    'mutton curry': 14.00,
    'paneer curry': 10.00

  
    
}

print(hotel_menu)

order = input('what would you like to order sir: ').lower()

total = 0
if order in hotel_menu:
    quantity = int(input('how many sir: '))
    print(f'{order} is added to your order')
    total = quantity * hotel_menu[order]
else:
    print('Sorry we do not have that item, Please order again..')
    

order_again = False
while not order_again:
    more_order = input("\nDo you need anything else: (yes/no)").lower()
    if more_order == 'y' or more_order == 'yes':
        order = input('what would you like to order sir: ').lower()

        if order in hotel_menu:
            quantity = int(input('how many sir: '))
            print(f'{order} is added to your order')
            total = total + (quantity * hotel_menu[order])
        else:
            print('Sorry we do not have that item...')       
    
    elif more_order == 'n' or more_order == 'no':
        order_again = True
    else:
        print('Invalid input')
        
        
print('Thank you for your order.')

print(f'Your total is: {total:.2f}')

# %%
print("Here is the Menu sir: ")
hotel_menu = {
    'chai': 3.50,
    'coffee': 3.50,
    'milk': 3.00,
    'water': 0,
    'buffet': 14.00,
    'chicken biryani': 10.00,
    'mutton biryani': 14.00,
    'chicken 65 biryani': 10.00,
    'paneer biryani': 10.00,
    'veg biryani': 9.00,
    'non-veg pulao': 12.00,
    'roti': 2.50,
    'butter naan': 4.00,
    'chicken curry': 10.00,
    'mutton curry': 14.00,
    'paneer curry': 10.00
}

print(hotel_menu)

total = 0

def take_order():
    order = input('What would you like to order, sir?: ').lower()
    return order

order = take_order()

if order in hotel_menu:
    quantity = int(input('How many sir?: '))
    print(f'{order} is added to your order')
    total = quantity * hotel_menu[order]
else:
    print('Sorry we do not have that item, Please order again..')
    

order_again = False
while not order_again:
    more_order = input("\nDo you need anything else: (yes/no)").lower()
    if more_order == 'y' or more_order == 'yes':
        order = take_order()

        if order in hotel_menu:
            quantity = int(input('How many sir?: '))
            print(f'{order} is added to your order')
            total = total + (quantity * hotel_menu[order])
        else:
            print('Sorry we do not have that item...')       
    
    elif more_order == 'n' or more_order == 'no':
        order_again = True
        
print('Thank you for your order.')

print(f'Your total is: {total:.2f}')
